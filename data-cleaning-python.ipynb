# %%
# Basic set up
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/itc-frank/Panama imp 2019.csv

# %% [markdown]
# ## Context:
#
# The Excel file Panama imp 2019.xlsx, presents Panama’s imports quantitative information (values and quantities) for the year 2019 at different level of aggregation: Total, by country, by country and product.
#
# The goal of the exercise is to re-structure the information and keep only quantitative information reported by product and country.
#
# Prepare a txt file with the different variables:
#
# - Flow
# - Period of time (year 2019)
# - Product code (numeral) "Code"
# - Partner country ("country")
# - Value ("CIF")
# - Quantity (net weight) ("net")
# The result file must look like this example:

# %%
df = pd.read_csv('/kaggle/input/itc-frank/Panama imp 2019.csv')
df.head(20)
# Out:
#              Code                                         Unnamed: 1    net  \
# 0             NaN                                            Albania  3,465
# 1   0910.99.90.00                                    Otras especies.     93
# 2   3926.90.49.00  Objetos  de  laboratorio  y  farmacia, incluso...    NaN
# 3             NaN                           calibrados, de plástico.      5
# 4   4819.40.19.00  Sacos (bolsas), multipliegos, de papel, cartón...    NaN
# 5             NaN  celulosa o napa  de  fibras  de  celulosa, exc...    NaN
# 6             NaN                     cemento, café molido o azúcar.     98
# 7   6104.43.10.00  Vestidos de punto, para mujeres, de fibras sin...      2
# 8   6104.69.00.00  Pantalones largos o cortos (calzones), con pet...    NaN
# 9             NaN  de punto, para  mujeres  o  niñas, de  las dem...    NaN
# 10            NaN                                          textiles.    125
# 11  6109.90.00.00  "T-shirts"  y  camisetas interiores, de punto,...    NaN
# 12            NaN                                 materias textiles.     19
# 13  6110.20.00.00  Suéteres (jerseys),  "pullovers",  "cardigans"...    NaN
# 14            NaN         artículos similares, de punto, de algodón.     12
# 15  6201.99.00.00  Anoraks, cazadoras y artículos  similares  par...    NaN
# 16            NaN  niños, de las demás  materias  textiles, excep...    NaN
# 17            NaN                                     partida 62.03.      2
# 18  6203.43.19.00  Los  demás  pantalones cortos (calzones), y "s...    NaN
# 19            NaN  hombres y niños, incluso con peto, de fibras s...      1
#
#        CIF    tax  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0   85,558  2,428         NaN         NaN         NaN         NaN         NaN
# 1    1,398    138         NaN         NaN         NaN         NaN         NaN
# 2      NaN    NaN         NaN         NaN         NaN         NaN         NaN
# 3      411     12         NaN         NaN         NaN         NaN         NaN
# 4      NaN    NaN         NaN         NaN         NaN         NaN         NaN
# 5      NaN    NaN         NaN         NaN         NaN         NaN         NaN
# 6      880    131         NaN         NaN         NaN         NaN         NaN
# 7      112     11         NaN         NaN         NaN         NaN         NaN
# 8      NaN    NaN         NaN         NaN         NaN         NaN         NaN
# 9      NaN    NaN         NaN         NaN         NaN         NaN         NaN
# 10   5,073    503         NaN         NaN         NaN         NaN         NaN
# 11     NaN    NaN         NaN         NaN         NaN         NaN         NaN
# 12   1,508    149         NaN         NaN         NaN         NaN         NaN
# 13     NaN    NaN         NaN         NaN         NaN         NaN         NaN
# 14     403     40         NaN         NaN         NaN         NaN         NaN
# 15     NaN    NaN         NaN         NaN         NaN         NaN         NaN
# 16     NaN    NaN         NaN         NaN         NaN         NaN         NaN
# 17     174     17         NaN         NaN         NaN         NaN         NaN
# 18     NaN    NaN         NaN         NaN         NaN         NaN         NaN
# 19     130     13         NaN         NaN         NaN         NaN         NaN
#
#     Unnamed: 10  Unnamed: 11
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4           NaN          NaN
# 5           NaN          NaN
# 6           NaN          NaN
# 7           NaN          NaN
# 8           NaN          NaN
# 9           NaN          NaN
# 10          NaN          NaN
# 11          NaN          NaN
# 12          NaN          NaN
# 13          NaN          NaN
# 14          NaN          NaN
# 15          NaN          NaN
# 16          NaN          NaN
# 17          NaN          NaN
# 18          NaN          NaN
# 19          NaN          NaN

# %% [markdown]
# ## Problems discovered:
# 1. Multiple rows should be merged into single records. (rows 2,3 should be merged, and rows 4, 5, 6 should be merged)
# 2. The country rows (ex. row 0) should be shaped into columns.
#
# In this step, we only care about columns: Code, net, CIF.

# %%
#Drop unamed columns
df= df.dropna(axis=1, how='all')

# %% [markdown]
# ## Pattern discovered:
# For each chunck of rows that are supposed to be merged into one record (here refer such chunck of rows as record): For Code column, valid info appears in the first row; for "net" and "CIF" columns, valide info apperas in the last row.
#
# For example, rows 4,5,6 are supposed to be merged into one record. The valid info for Code column appears in row 4, and the valid info for "net" and "CIF" columns appear in row 6.
#
# Given this pattern, I use forward fill `.ffill()` and backword fill `.bfill()` to replace the `NaN` value with either the first row or last row per record.

# %%
df["Code"]=df["Code"].ffill()
df["net"]=df["net"].bfill()
df["CIF"]=df["CIF"].bfill()
#Let's look at the result
df.head(10)
# Out:
#             Code                                         Unnamed: 1    net  \
# 0            NaN                                            Albania  3,465
# 1  0910.99.90.00                                    Otras especies.     93
# 2  3926.90.49.00  Objetos  de  laboratorio  y  farmacia, incluso...      5
# 3  3926.90.49.00                           calibrados, de plástico.      5
# 4  4819.40.19.00  Sacos (bolsas), multipliegos, de papel, cartón...     98
# 5  4819.40.19.00  celulosa o napa  de  fibras  de  celulosa, exc...     98
# 6  4819.40.19.00                     cemento, café molido o azúcar.     98
# 7  6104.43.10.00  Vestidos de punto, para mujeres, de fibras sin...      2
# 8  6104.69.00.00  Pantalones largos o cortos (calzones), con pet...    125
# 9  6104.69.00.00  de punto, para  mujeres  o  niñas, de  las dem...    125
#
#       CIF    tax
# 0  85,558  2,428
# 1   1,398    138
# 2     411    NaN
# 3     411     12
# 4     880    NaN
# 5     880    NaN
# 6     880    131
# 7     112     11
# 8   5,073    NaN
# 9   5,073    NaN

# %% [markdown]
# ## Extract country info
# Extract country info from rows and save it as a column named "country".
# 1. Identify which rows don't contain country info: no space, and doesn't end with "."
# 2. Create a column called "country" = the identified country rows

# %%
# Identify which rows contain country info: the rows that don't contain space " " or 
a = df[~(df['Unnamed: 1'].str.contains(" ")|df['Unnamed: 1'].str.endswith("."))]

df["country"]=a["Unnamed: 1"]
df.head(10)
# Out:
#             Code                                         Unnamed: 1    net  \
# 0            NaN                                            Albania  3,465
# 1  0910.99.90.00                                    Otras especies.     93
# 2  3926.90.49.00  Objetos  de  laboratorio  y  farmacia, incluso...      5
# 3  3926.90.49.00                           calibrados, de plástico.      5
# 4  4819.40.19.00  Sacos (bolsas), multipliegos, de papel, cartón...     98
# 5  4819.40.19.00  celulosa o napa  de  fibras  de  celulosa, exc...     98
# 6  4819.40.19.00                     cemento, café molido o azúcar.     98
# 7  6104.43.10.00  Vestidos de punto, para mujeres, de fibras sin...      2
# 8  6104.69.00.00  Pantalones largos o cortos (calzones), con pet...    125
# 9  6104.69.00.00  de punto, para  mujeres  o  niñas, de  las dem...    125
#
#       CIF    tax  country
# 0  85,558  2,428  Albania
# 1   1,398    138      NaN
# 2     411    NaN      NaN
# 3     411     12      NaN
# 4     880    NaN      NaN
# 5     880    NaN      NaN
# 6     880    131      NaN
# 7     112     11      NaN
# 8   5,073    NaN      NaN
# 9   5,073    NaN      NaN

# %% [markdown]
# **Further clean the data by dropping dulicate values in "Code" column.**

# %%
df.drop_duplicates('Code', inplace=True)
df.head(10)
# Out:
#              Code                                         Unnamed: 1    net  \
# 0             NaN                                            Albania  3,465
# 1   0910.99.90.00                                    Otras especies.     93
# 2   3926.90.49.00  Objetos  de  laboratorio  y  farmacia, incluso...      5
# 4   4819.40.19.00  Sacos (bolsas), multipliegos, de papel, cartón...     98
# 7   6104.43.10.00  Vestidos de punto, para mujeres, de fibras sin...      2
# 8   6104.69.00.00  Pantalones largos o cortos (calzones), con pet...    125
# 11  6109.90.00.00  "T-shirts"  y  camisetas interiores, de punto,...     19
# 13  6110.20.00.00  Suéteres (jerseys),  "pullovers",  "cardigans"...     12
# 15  6201.99.00.00  Anoraks, cazadoras y artículos  similares  par...      2
# 18  6203.43.19.00  Los  demás  pantalones cortos (calzones), y "s...      1
#
#        CIF    tax  country
# 0   85,558  2,428  Albania
# 1    1,398    138      NaN
# 2      411    NaN      NaN
# 4      880    NaN      NaN
# 7      112     11      NaN
# 8    5,073    NaN      NaN
# 11   1,508    NaN      NaN
# 13     403    NaN      NaN
# 15     174    NaN      NaN
# 18     130    NaN      NaN

# %% [markdown]
# **Fill all the `NaN` values in column "country" with the first valid country info pre chunck, using `.ffill()` forward fill.**

# %%
df["country"] =df["country"].ffill()
df.head(10)
# Out:
#              Code                                         Unnamed: 1    net  \
# 0             NaN                                            Albania  3,465
# 1   0910.99.90.00                                    Otras especies.     93
# 2   3926.90.49.00  Objetos  de  laboratorio  y  farmacia, incluso...      5
# 4   4819.40.19.00  Sacos (bolsas), multipliegos, de papel, cartón...     98
# 7   6104.43.10.00  Vestidos de punto, para mujeres, de fibras sin...      2
# 8   6104.69.00.00  Pantalones largos o cortos (calzones), con pet...    125
# 11  6109.90.00.00  "T-shirts"  y  camisetas interiores, de punto,...     19
# 13  6110.20.00.00  Suéteres (jerseys),  "pullovers",  "cardigans"...     12
# 15  6201.99.00.00  Anoraks, cazadoras y artículos  similares  par...      2
# 18  6203.43.19.00  Los  demás  pantalones cortos (calzones), y "s...      1
#
#        CIF    tax  country
# 0   85,558  2,428  Albania
# 1    1,398    138  Albania
# 2      411    NaN  Albania
# 4      880    NaN  Albania
# 7      112     11  Albania
# 8    5,073    NaN  Albania
# 11   1,508    NaN  Albania
# 13     403    NaN  Albania
# 15     174    NaN  Albania
# 18     130    NaN  Albania

# %% [markdown]
# **Delete the columns that we don't need anymore**

# %%
del df["tax"]
del df["Unnamed: 1"]
df.head(25)
# Out:
#              Code    net     CIF  country
# 0             NaN  3,465  85,558  Albania
# 1   0910.99.90.00     93   1,398  Albania
# 2   3926.90.49.00      5     411  Albania
# 4   4819.40.19.00     98     880  Albania
# 7   6104.43.10.00      2     112  Albania
# 8   6104.69.00.00    125   5,073  Albania
# 11  6109.90.00.00     19   1,508  Albania
# 13  6110.20.00.00     12     403  Albania
# 15  6201.99.00.00      2     174  Albania
# 18  6203.43.19.00      1     130  Albania
# 20  6204.12.29.00      2     171  Albania
# 21  6204.43.10.00      3     179  Albania
# 22  6204.69.19.00     30   2,339  Albania
# 25  6204.69.29.00     29   1,527  Albania
# 27  6206.40.10.00      2     249  Albania
# 29  6402.99.96.00     30   1,101  Albania
# 32  6403.91.94.00      9     436  Albania
# 35  6403.91.96.00     11     554  Albania
# 39  6403.91.97.00      1     114  Albania
# 42  6403.99.10.00     50   4,252  Albania
# 45  6403.99.94.00     10     643  Albania
# 48  6403.99.95.00     10     837  Albania
# 51  6403.99.96.00     60   3,854  Albania
# 54  6403.99.97.00     16   1,276  Albania
# 57  8419.89.10.00  2,739  54,786  Albania

# %% [markdown]
# **Rename columns**

# %%
df.rename(columns={'CIF': 'value', 'net': 'quantity', 'country':'partner','Code':'product_code'}, inplace=True)
df.head(25)
# Out:
#      product_code quantity   value  partner
# 0             NaN    3,465  85,558  Albania
# 1   0910.99.90.00       93   1,398  Albania
# 2   3926.90.49.00        5     411  Albania
# 4   4819.40.19.00       98     880  Albania
# 7   6104.43.10.00        2     112  Albania
# 8   6104.69.00.00      125   5,073  Albania
# 11  6109.90.00.00       19   1,508  Albania
# 13  6110.20.00.00       12     403  Albania
# 15  6201.99.00.00        2     174  Albania
# 18  6203.43.19.00        1     130  Albania
# 20  6204.12.29.00        2     171  Albania
# 21  6204.43.10.00        3     179  Albania
# 22  6204.69.19.00       30   2,339  Albania
# 25  6204.69.29.00       29   1,527  Albania
# 27  6206.40.10.00        2     249  Albania
# 29  6402.99.96.00       30   1,101  Albania
# 32  6403.91.94.00        9     436  Albania
# 35  6403.91.96.00       11     554  Albania
# 39  6403.91.97.00        1     114  Albania
# 42  6403.99.10.00       50   4,252  Albania
# 45  6403.99.94.00       10     643  Albania
# 48  6403.99.95.00       10     837  Albania
# 51  6403.99.96.00       60   3,854  Albania
# 54  6403.99.97.00       16   1,276  Albania
# 57  8419.89.10.00    2,739  54,786  Albania

# %% [markdown]
# **Remove missing values**

# %%
df = df[df['product_code'].notna()]
df = df[df['value'].notna()]
df.head(25)
# Out:
#      product_code quantity   value  partner
# 1   0910.99.90.00       93   1,398  Albania
# 2   3926.90.49.00        5     411  Albania
# 4   4819.40.19.00       98     880  Albania
# 7   6104.43.10.00        2     112  Albania
# 8   6104.69.00.00      125   5,073  Albania
# 11  6109.90.00.00       19   1,508  Albania
# 13  6110.20.00.00       12     403  Albania
# 15  6201.99.00.00        2     174  Albania
# 18  6203.43.19.00        1     130  Albania
# 20  6204.12.29.00        2     171  Albania
# 21  6204.43.10.00        3     179  Albania
# 22  6204.69.19.00       30   2,339  Albania
# 25  6204.69.29.00       29   1,527  Albania
# 27  6206.40.10.00        2     249  Albania
# 29  6402.99.96.00       30   1,101  Albania
# 32  6403.91.94.00        9     436  Albania
# 35  6403.91.96.00       11     554  Albania
# 39  6403.91.97.00        1     114  Albania
# 42  6403.99.10.00       50   4,252  Albania
# 45  6403.99.94.00       10     643  Albania
# 48  6403.99.95.00       10     837  Albania
# 51  6403.99.96.00       60   3,854  Albania
# 54  6403.99.97.00       16   1,276  Albania
# 57  8419.89.10.00    2,739  54,786  Albania
# 58  9802.00.20.00      106   3,151  Albania

# %% [markdown]
# **Transform Quantity and value from string type to numeric type:**
#
# 1. Remove the `,` in the string
# 2. Transform string to numeric type

# %%
df["value"]=df['value'].str.replace(r'\D', '')
df['value'] = pd.to_numeric(df['value'])

df["quantity"]=df['quantity'].str.replace(r'\D', '')
df['quantity'] = pd.to_numeric(df['quantity'])
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   after removing the cwd from sys.path.

# %% [markdown]
# ## Create additional variables
# based on the task description
#
# 1. flow variable
# 2. year variable

# %%
df["flow"]= np.where(df["value"]>0, 1, 2)
df["year"]= 2019
df.head(25)
# Out:
#      product_code  quantity  value  partner  flow  year
# 1   0910.99.90.00        93   1398  Albania     1  2019
# 2   3926.90.49.00         5    411  Albania     1  2019
# 4   4819.40.19.00        98    880  Albania     1  2019
# 7   6104.43.10.00         2    112  Albania     1  2019
# 8   6104.69.00.00       125   5073  Albania     1  2019
# 11  6109.90.00.00        19   1508  Albania     1  2019
# 13  6110.20.00.00        12    403  Albania     1  2019
# 15  6201.99.00.00         2    174  Albania     1  2019
# 18  6203.43.19.00         1    130  Albania     1  2019
# 20  6204.12.29.00         2    171  Albania     1  2019
# 21  6204.43.10.00         3    179  Albania     1  2019
# 22  6204.69.19.00        30   2339  Albania     1  2019
# 25  6204.69.29.00        29   1527  Albania     1  2019
# 27  6206.40.10.00         2    249  Albania     1  2019
# 29  6402.99.96.00        30   1101  Albania     1  2019
# 32  6403.91.94.00         9    436  Albania     1  2019
# 35  6403.91.96.00        11    554  Albania     1  2019
# 39  6403.91.97.00         1    114  Albania     1  2019
# 42  6403.99.10.00        50   4252  Albania     1  2019
# 45  6403.99.94.00        10    643  Albania     1  2019
# 48  6403.99.95.00        10    837  Albania     1  2019
# 51  6403.99.96.00        60   3854  Albania     1  2019
# 54  6403.99.97.00        16   1276  Albania     1  2019
# 57  8419.89.10.00      2739  54786  Albania     1  2019
# 58  9802.00.20.00       106   3151  Albania     1  2019

# %% [markdown]
# ## Export results

# %%
df = df[["flow", "year", "product_code", "partner", "value", "quantity"]]
df.to_csv('result.txt', header=None, index=None, sep=' ', mode='a')
